# %% [markdown]
# <a href="https://colab.research.google.com/github/Nida0709/lab/blob/main/Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""Practice01"""
#Hello Worldを表示させる
print("Hello World")
print("Hello" " Python")

# %%
#Google Driveとの連携
# !pip install -D -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
#ファイルを開いてデータを取得
#ファイルにあるパス
data_Path = "/content/drive/MyDrive/研究/実験データ/Savitzky-Golay(11次元)_cnf-fr10_100g_20mms_1.xlsx"

wb_temp = openpyxl.load_workbook(data_Path)
sheet_temp = wb_temp["Sheet1"]


#読み込んだデータをDBに保管
DB = list(sheet_temp.rows)

#使い方
print(DB[2][1].value)

# %%
#Chrome上でのアップロード&ダウンロード
from google.colab import files
#ファイルのアップロード
#ファイルはGoogleDrive(Colaboratory上のDrive)contentに格納される
files.upload()
#ファイルを開いてデータを取得
with open("test_data.txt","r") as tf:
  list1 = tf.read().split("\n")
  for count_list1 in range(len(list1)):
    print(list1[count_list1])
#新たにファイルを作成
#リストの各要素をファイル名にし、その要素だけを含んだtxtファイルを作る
  for count_list1 in range(len(list1)):
    fname = list1[count_list1] + ".txt"
    with open(fname,"w") as opf:
      opf.write(list1[count_list1])
#GoogleDrive上にファイルがアップされる
  for count_list1 in range(len(list1)):
    fdname = list1[count_list1] + ".txt"
    files.download(fdname)

# %%
import numpy as np
from matplotlib import pyplot as plt


x= np.linspace(-10,10,20)
y= x**3 +  2*x**2 + 3*x + 10+ np.random.randn(20)*50

#近似式の係数
res1=np.polyfit(x, y, 1)
res2=np.polyfit(x, y, 2)
res3=np.polyfit(x, y, 3)
#近似式の計算
y1 = np.poly1d(res1)(x) #1次
y2 = np.poly1d(res2)(x) #2次
y3 = np.poly1d(res3)(x) #3次

#グラフ表示
plt.scatter(x, y, label='元データ')
plt.plot(x, y1, label='1次')
plt.plot(x, y2, label='2次')
plt.plot(x, y3, label='3次')
plt.legend()
plt.show()
